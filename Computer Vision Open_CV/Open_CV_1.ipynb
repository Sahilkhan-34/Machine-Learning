# %%
import cv2

# %%
image = cv2.imread(r"C:\Users\sahil\Downloads\actor.jpg")

# %%
image.shape
# Out:
# (1072, 800, 3)

# %% [markdown]
# - Using openCV method
# - Every image we have height and width
# - if its color image (height, width, color)
# - Color: R, G, B ()
# - we have two kind of images Gray and Color
# - gray
#     - values always lies between 0 and 1
#     - 0 mean black and 1 means white
#
# - color
#     - VIBGYOR : 2*7 = 128 -- 2 means bineary 0, 1  and 7 means 7 Colors
#     - 0 to 255
#     - No color  = Black : 0
#     - V+I+B+G+Y+O+R = White : 1
#
# - When you Open Image, It will open New Window
# - And Image Will be display on the window
# - If you want to close the window press : 0 (always do this with 0 not X cross mark it trubles the kernel)

# %%
image = cv2.imread(r"C:\Users\sahil\Downloads\actor.jpg")
cv2.imshow('ABD', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (1072, 800, 3)

# %%
image[0].shape
# Out:
# (800, 3)

# %% [markdown]
# ### Method 2 - Google Colab
# - google colab patches : cv2_imshow()

# %% [markdown]
# ### Method 3 - Pillow Package

# %%
from PIL import Image

# %%
image = Image.open(r"C:\Users\sahil\Downloads\actress.jpg")
image.show() # open in new window

# %%
image # it open below cell
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=815x540>

# %% [markdown]
# ### Method 4 - Matplotlib Package

# %%
import matplotlib.pyplot as plt
# Open image using pillow
from PIL import Image

# %%
image = Image.open(r"C:\Users\sahil\Downloads\actress.jpg")
# show the image using the matplotlib
plt.imshow(image)

# %% [markdown]
# ### Writing the images

# %%
import cv2

image = cv2.imread(r"C:\Users\sahil\Downloads\actress.jpg")
cv2.imwrite('output1.jpg', image) # small in size 
cv2.imwrite('output2.png', image) # large in size
# Out:
# True
